# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Exercício 1
#
# - Crie um array x com 200 pontos, começando de -10 até 10. Depois calcule as seguintes funções sobre esse array:
#
#
# y1 = sen(x) / x
#
#
# y2 = 1 / (1-e^(-x))
#
#
# Por fim, plot essas duas funções, em função do x, ambas em uma mesma figura, porém, em dois axes distintos (um abaixo do outro).

# %%
x = np.linspace(-10, 10, 200)
y1 = np.sin(x)/x
y2 = 1/(1 - np.exp(-x))

# %%
plt.subplot(2, 1, 1)
plt.plot(x, y1)

plt.subplot(2, 1, 2)
plt.plot(x, y2)

plt.tight_layout()

# %% [markdown]
# ### Exercício 2
#
# Carregue o arquivo avocado.csv e, em seguida, siga as instruções abaixo:
#
# (a) Obtenha apenas os dados desse dataset que são referentes à região da Califórnia (California), no ano de 2017; e salva-os em um novo dataframe.
#
# (b) A partir do dataframe obtido no item (a), obtenha apenas os dados referentes à abacates do tipo convencional; em seguida, salve em um novo dataframe.
#
# (c) Utilizando o dataframe salvo no item (b), crie um gráfico de linha que apresente a variação do preço médio do abacate ao longo do ano de 2017 (datas) na região da Califórnia.
#
# (d) Utilizando o dataframe salvo no item (a), crie um gráfico de pizza que apresente o percentual do volume total de abacates vendidos para cada tipo: convencional e orgânico.

# %%
df = pd.read_csv('../../data_sets/Avocado.csv')

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume  year  region          type
# 0  2015-12-27          1.33      64236.62  2015  Albany  conventional
# 1  2015-12-20          1.35      54876.98  2015  Albany  conventional
# 2  2015-12-13          0.93     118220.22  2015  Albany  conventional
# 3  2015-12-06          1.08      78992.15  2015  Albany  conventional
# 4  2015-11-29          1.28      51039.60  2015  Albany  conventional

# %%
#a
df_calif = df[(df['region'] == 'California') & (df['year'] == 2017)]

# %%
df_calif
# Out:
#              Date  AveragePrice  Total Volume  year      region          type
# 5934   2017-12-31          0.93    7132711.23  2017  California  conventional
# 5935   2017-12-24          1.13    5346535.57  2017  California  conventional
# 5936   2017-12-17          0.98    6205211.05  2017  California  conventional
# 5937   2017-12-10          1.06    5715712.21  2017  California  conventional
# 5938   2017-12-03          1.09    5544556.00  2017  California  conventional
# ...           ...           ...           ...   ...         ...           ...
# 15107  2017-01-29          1.44     165225.54  2017  California       organic
# 15108  2017-01-22          1.53     136422.97  2017  California       organic
# 15109  2017-01-15          1.66     142739.21  2017  California       organic
# 15110  2017-01-08          1.50     177777.40  2017  California       organic
# 15111  2017-01-01          1.46     164137.04  2017  California       organic
#
# [106 rows x 6 columns]

# %%
#b
df_convenc = df_calif[df_calif['type'] == 'conventional']

# %%
df_convenc.shape
# Out:
# (53, 6)

# %%
#c
plt.figure(figsize=(15, 10))
plt.plot(df_convenc['Date'], df_convenc['AveragePrice'], label='Preço/data')
plt.xticks(rotation=60, fontsize=12)
plt.legend(fontsize=18)
plt.tight_layout()
plt.show()

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
#d
tipos = df['type'].value_counts()
plt.pie(df['type'].value_counts(), autopct='%.2f%%', labels=tipos.index, shadow=True, radius=2,
        textprops={'fontsize':14, 'color':'white'},
        wedgeprops = { 'linewidth' : 2 , 'edgecolor' : 'lightgrey'})
plt.show()

# %% [markdown]
# ## Exercício 3
#
# Carregue o dataset contido no arquivo cholera-dataset.csv em um objeto DataFrame. Esse dataset contém dados referentes ao número de casos reportados de cólera em cada país, desde 1950 até 2016, além do número de mortes provocadas pela cólera; dentre outras informações.
#
# Após carregar esse dataset, obtenha:
#
#
# (a) Apenas os dados da Índia.
#
# (b) Crie um gráfico de barras que apresente o número de casos reportados e de mortes causadas pela cólera na Índia, ambos em um mesmo axes, em função do ano.

# %%
df = pd.read_csv('../../data_sets/cholera-dataset.csv')

df.head()
# Out:
#        Country  Year  Number of reported cases of cholera  \
# 0  Afghanistan  2016                                677.0
# 1  Afghanistan  2015                              58064.0
# 2  Afghanistan  2014                              45481.0
# 3  Afghanistan  2013                               3957.0
# 4  Afghanistan  2012                                 12.0
#
#    Number of reported deaths from cholera  Cholera case fatality rate  \
# 0                                     5.0                        0.70
# 1                                     8.0                        0.01
# 2                                     4.0                        0.00
# 3                                    14.0                        0.35
# 4                                     0.0                        0.10
#
#               WHO Region
# 0  Eastern Mediterranean
# 1  Eastern Mediterranean
# 2  Eastern Mediterranean
# 3  Eastern Mediterranean
# 4  Eastern Mediterranean

# %%
#a
casos_india = df[df['Country'] == 'India']

# %%
#b
plt.figure(figsize=(10, 5))
plt.style.use('seaborn')
plt.bar(casos_india['Year'] - 0.2, casos_india['Number of reported cases of cholera'], width=0.35,
       label='Casos de Cólera')
plt.bar(casos_india['Year'] + 0.2, casos_india['Number of reported deaths from cholera'], width=0.35,
       label='Mortes pela Cólera')
plt.legend()

# %% [markdown]
# ## Exercício 4
# (a) Crie um gráfico de pizza que apresente o percentual dos gêneros (Genres) dos aplicativos. Como existem muitos gêneros, considere apenas os 10 primeiros.
#
# (b) Crie um gráfico de barras que contenha a quantidade de aplicativos que foram desenvolvidos para cada versão específica (ou conjunto de versões) do Android, especificadas na coluna Android Ver.

# %%
df = pd.read_csv('../../data_sets/googleplaystore.csv')

# %%
#a
generos = df[:10]['Genres'].value_counts()

plt.pie(generos, labels=generos.index, autopct='%.2f%%',
        textprops={'color':'white', 'fontsize':12},
       counterclock=False, wedgeprops = { 'linewidth' : 2 , 'edgecolor' : 'lightgrey'})

plt.show()

# %%
df.shape
# Out:
# (10841, 13)

# %%
#b
versoes = df['Android Ver'].value_counts()

plt.figure(figsize=(10,5))
plt.bar(versoes.index, versoes)

plt.xlabel('Versões', fontsize=14)
plt.ylabel('Quantidade de apps', fontsize=14)

plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# Carregue o arquivo houses_to_rent.csv. Em seguida:
#
# (a) Crie um gráfico de dispersão para visualizar uma relação entre a área e o preço total do aluguel do imóvel.
#
# (b) Visualize os outliers presentes na coluna da área utilizando o boxplot.
#
# (c) Faça o mesmo que foi solicitado no item anterior, porém, para a coluna do preço total do aluguel.
#
# (d) Elimine os outliers de ambas as colunas utilizando o método quantile.
#
# (e) Crie novamente um gráfico
# de dispersão dos dados da área e preço total do aluguel do imóvel;
# dessa vez, após a remoção dos outliers de ambas as colunas.

# %%
import seaborn as sns

# %%
df = pd.read_csv('../../data_sets/houses_to_rent.csv')

df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 0     São Paulo    70      2         1               1     7      acept
# 1     São Paulo   320      4         4               0    20      acept
# 2  Porto Alegre    80      1         1               1     6      acept
# 3  Porto Alegre    51      2         1               0     2      acept
# 4     São Paulo    25      1         1               0     1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841
# 3                   17        1421
# 4                   11         836

# %%
#a
plt.scatter(df['area'], df['total (R$)'])
plt.axis([0, 50000, 0, 60000])
plt.xlabel('Area', fontsize=12)
plt.ylabel('Preço', fontsize=12)
plt.tight_layout()

# %%
#b
sns.boxplot(data=df, x='area')
# Out:
# <AxesSubplot:xlabel='area'>

# %%
plt.boxplot(df['area'])
plt.show()

# %%
#c
sns.boxplot(data=df, x='total (R$)')
# Out:
# <AxesSubplot:xlabel='total (R$)'>

# %%
plt.boxplot(df['total (R$)'])
plt.show()

# %%
# d
q1_area = df['area'].quantile(0.25)
q2_area = df['area'].quantile(0.5)
q3_area = df['area'].quantile(0.75)

q1_preco = df['total (R$)'].quantile(0.25)
q2_preco = df['total (R$)'].quantile(0.5)
q3_preco = df['total (R$)'].quantile(0.75)

IQR_AREA = q3_area - q1_area
IQR_PRECO = q3_preco - q1_preco

# %%
l_inf_area = max(df['area'].min() ,q1_area - (IQR_AREA * 1.5))
l_sup_area = min(df['area'].max() ,q3_area + (IQR_AREA * 1.5))

l_sup_preco = min(df['total (R$)'].max(),q3_preco + (IQR_PRECO * 1.5))

# %%
sns.boxplot(data=df[df['area'] <= l_sup_area], x='area')
# Out:
# <AxesSubplot:xlabel='area'>

# %%
sns.boxplot(data=df[df['total (R$)'] < l_sup_preco], x='total (R$)')
# Out:
# <AxesSubplot:xlabel='total (R$)'>

# %%
plt.boxplot(df['area'] < l_sup_area)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f0c92b0>,
#   <matplotlib.lines.Line2D at 0x1f0c93a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f0c9a18>,
#   <matplotlib.lines.Line2D at 0x1f0c9da8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f0c9070>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f0c9ef8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f374aa8>],
#  'means': []}

# %%
plt.boxplot(df['total (R$)'] < l_sup_preco)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ffcd6e8>,
#   <matplotlib.lines.Line2D at 0x1ffcd6d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ffcdf40>,
#   <matplotlib.lines.Line2D at 0x1ffcd268>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ffcd220>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ef55040>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ef55508>],
#  'means': []}

# %%
# e
df2 = df.drop(np.where(df['area'] > l_sup_area)[0]).reset_index(drop=True)

# %%
df2.drop(np.where(df2['total (R$)'] > l_sup_preco)[0], inplace=True)

# %%
plt.scatter(df2['area'], df2['total (R$)'])
plt.xlabel('Area', fontsize=12)
plt.ylabel('Preço', fontsize=12)
plt.tight_layout()

# %%
sns.lmplot(data=df2, x='area', y='total (R$)')
